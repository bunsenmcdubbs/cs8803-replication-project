# %% [markdown]
# # Entity Recognition from Parsed Data
#
# This notebook is an extention of the `entity_recognition_prototype.ipynb` to enable the usage of parsed data provided by the original authors of the paper.
#
# Please see the other notebook for documentation and explanation about methods.

# %%
import os
import sys
preproc_path = os.path.abspath(os.path.join('..'))
print(preproc_path)
if preproc_path not in sys.path:
    sys.path.append(preproc_path)
# Out:
# /Users/andrew/Documents/college/cs8803-css/replication-project/code/src

# %%
import json
parsed_data_path = '../../data/data-from-authors/train_data/AFP_ENG_20090609.0525.json'
parsed_data = json.load(open(parsed_data_path, 'r'))
parsed_data.keys()
# Out:
# dict_keys(['docId', 'headline', 'named_entity', 'cluster_json', 'text', 'part_of_speech', 'totalParse', 'processed'])

# %% [markdown]
# - `docId`
# - `headline`
# - `named_entity` named entities and occurances
# - `cluster_json` co-reference chains
# - `text` tokens by sentence
# - `part_of_speech`
# - `totalParse`
# - `processed`

# %% [markdown]
# ## Transforming annotation format
#
# First, we'll do our best to transform the given parsed data into a skeleton of the token annotation used by Stanford CoreNLP's API.

# %%
sentences = [
    {
        'index': s_idx,
        'tokens': [
            {
                'index': t_idx + 1, # index starting at 1
                'originalText': token
            }
            for t_idx, token in enumerate(sentence)
        ]
    }
    for s_idx, sentence in enumerate(parsed_data['text'])
]

sentences
# Out:
# [{'index': 0,
#   'tokens': [{'index': 1, 'originalText': 'EU'},
#    {'index': 2, 'originalText': 'seeks'},
#    {'index': 3, 'originalText': 'common'},
#    {'index': 4, 'originalText': 'strategy'},
#    {'index': 5, 'originalText': 'on'},
#    {'index': 6, 'originalText': 'swine'},
#    {'index': 7, 'originalText': 'flu'},
#    {'index': 8, 'originalText': 'vaccine'},
#    {'index': 9, 'originalText': '.'}]},
#  {'index': 1,
#   'tokens': [{'index': 1, 'originalText': 'EU'},
#    {'index': 2, 'originalText': 'Health'},
#    {'index': 3, 'originalText': 'Commissioner'},
#    {'index': 4, 'originalText': 'Androulla'},
#    {'index': 5, 'originalText': 'Vassiliou'},
#    {'index': 6, 'originalText': 'on'},
#    {'index': 7, 'originalText': 'Tuesday'},
#    {'index': 8, 'originalText': 'called'},
#    {'index': 9, 'originalText': 'for'},
#    {'index': 10, 'originalText': 'a'},
#    {'index': 11, 'originalText': 'common'},
#    {'index': 12, 'originalText': 'European'},
#    {'index': 13, 'originalText': 'strategy'},
#    {'index': 14, 'originalText': 'on'},
#    {'index': 15, 'originalText': 'producing'},
#    {'index': 16, 'originalText': 'and'},
#    {'index': 17, 'originalText': 'using'},
#    {'index': 18, 'originalText': 'a'},
#    {'index': 19, 'originalText': 'swine'},
#    {'index': 20, 'originalText': 'flu'},
#    {'index': 21, 'originalText': 'vaccine'},
#    {'index': 22, 'originalText': ','},
#    {'index': 23, 'originalText': 'emphasising'},
#    {'index': 24, 'originalText': 'the'},
#    {'index': 25, 'originalText': 'need'},
#    {'index': 26, 'originalText': 'to'},
#    {'index': 27, 'originalText': 'focus'},
#    {'index': 28, 'originalText': 'on'},
#    {'index': 29, 'originalText': 'those'},
#    {'index': 30, 'originalText': 'most'},
#    {'index': 31, 'originalText': 'vulnerable'},
#    {'index': 32, 'originalText': '.'}]},
#  {'index': 2,
#   'tokens': [{'index': 1, 'originalText': '``'},
#    {'index': 2, 'originalText': 'I'},
#    {'index': 3, 'originalText': 'think'},
#    {'index': 4, 'originalText': 'it'},
#    {'index': 5, 'originalText': 'is'},
#    {'index': 6, 'originalText': 'very'},
#    {'index': 7, 'originalText': 'important'},
#    {'index': 8, 'originalText': 'member'},
#    {'index': 9, 'originalText': 'states'},
#    {'index': 10, 'originalText': 'reach'},
#    {'index': 11, 'originalText': 'agreement'},
#    {'index': 12, 'originalText': 'on'},
#    {'index': 13, 'originalText': 'the'},
#    {'index': 14, 'originalText': 'modalities'},
#    {'index': 15, 'originalText': 'of'},
#    {'index': 16, 'originalText': 'production'},
#    {'index': 17, 'originalText': ','},
#    {'index': 18, 'originalText': 'availability'},
#    {'index': 19, 'originalText': 'and'},
#    {'index': 20, 'originalText': 'distribution'},
#    {'index': 21, 'originalText': 'of'},
#    {'index': 22, 'originalText': 'the'},
#    {'index': 23, 'originalText': 'vaccine'},
#    {'index': 24, 'originalText': ','},
#    {'index': 25, 'originalText': "''"},
#    {'index': 26, 'originalText': 'she'},
#    {'index': 27, 'originalText': 'told'},
#    {'index': 28, 'originalText': 'reporters'},
#    {'index': 29, 'originalText': 'as'},
#    {'index': 30, 'originalText': 'she'},
#    {'index': 31, 'originalText': 'arrived'},
#    {'index': 32, 'originalText': 'for'},
#    {'index': 33, 'originalText': 'a'},
#    {'index': 34, 'originalText': 'meeting'},
#    {'index': 35, 'originalText': 'of'},
#    {'index': 36, 'originalText': 'EU'},
#    {'index': 37, 'originalText': 'health'},
#    {'index': 38, 'originalText': 'ministers'},
#    {'index': 39, 'originalText': 'in'},
#    {'index': 40, 'originalText': 'Luxembourg'},
#    {'index': 41, 'originalText': '.'}]},
#  {'index': 3,
#   'tokens': [{'index': 1, 'originalText': '``'},
#    {'index': 2, 'originalText': 'We'},
#    {'index': 3, 'originalText': 'need'},
#    {'index': 4, 'originalText': 'to'},
#    {'index': 5, 'originalText': 'have'},
#    {'index': 6, 'originalText': 'a'},
#    {'index': 7, 'originalText': 'vaccine'},
#    {'index': 8, 'originalText': 'by'},
#    {'index': 9, 'originalText': 'the'},
#    {'index': 10, 'originalText': 'autumn'},
#    {'index': 11, 'originalText': ','},
#    {'index': 12, 'originalText': 'and'},
#    {'index': 13, 'originalText': 'if'},
#    {'index': 14, 'originalText': 'there'},
#    {'index': 15, 'originalText': 'is'},
#    {'index': 16, 'originalText': 'not'},
#    {'index': 17, 'originalText': 'enough'},
#    {'index': 18, 'originalText': 'vaccine'},
#    {'index': 19, 'originalText': 'for'},
#    {'index': 20, 'originalText': 'everyone'},
#    {'index': 21, 'originalText': 'then'},
#    {'index': 22, 'originalText': 'we'},
#    {'index': 23, 'originalText': 'need'},
#    {'index': 24, 'originalText': 'to'},
#    {'index': 25, 'originalText': 'decide'},
#    {'index': 26, 'originalText': 'on'},
#    {'index': 27, 'originalText': 'priority'},
#    {'index': 28, 'originalText': 'groups'},
#    {'index': 29, 'originalText': 'to'},
#    {'index': 30, 'originalText': 'be'},
#    {'index': 31, 'originalText': 'vaccinated'},
#    {'index': 32, 'originalText': 'first'},
#    {'index': 33, 'originalText': ','},
#    {'index': 34, 'originalText': "''"},
#    {'index': 35, 'originalText': 'such'},
#    {'index': 36, 'originalText': 'as'},
#    {'index': 37, 'originalText': 'the'},
#    {'index': 38, 'originalText': 'elderly'},
#    {'index': 39, 'originalText': 'and'},
#    {'index': 40, 'originalText': 'the'},
#    {'index': 41, 'originalText': 'handicapped'},
#    {'index': 42, 'originalText': ','},
#    {'index': 43, 'originalText': "''"},
#    {'index': 44, 'originalText': 'she'},
#    {'index': 45, 'originalText': 'added'},
#    {'index': 46, 'originalText': '.'}]},
#  {'index': 4,
#   'tokens': [{'index': 1, 'originalText': '``'},
#    {'index': 2, 'originalText': 'We'},
#    {'index': 3, 'originalText': 'wo'},
#    {'index': 4, 'originalText': "n't"},
#    {'index': 5, 'originalText': 'have'},
#    {'index': 6, 'originalText': 'enormous'},
#    {'index': 7, 'originalText': 'quantities'},
#    {'index': 8, 'originalText': 'of'},
#    {'index': 9, 'originalText': 'the'},
#    {'index': 10, 'originalText': 'vaccine'},
#    {'index': 11, 'originalText': 'available'},
#    {'index': 12, 'originalText': 'from'},
#    {'index': 13, 'originalText': 'day'},
#    {'index': 14, 'originalText': 'one'},
#    {'index': 15, 'originalText': '.'},
#    {'index': 16, 'originalText': "''"}]},
#  {'index': 5,
#   'tokens': [{'index': 1, 'originalText': 'The'},
#    {'index': 2, 'originalText': 'possibility'},
#    {'index': 3, 'originalText': 'of'},
#    {'index': 4, 'originalText': 'the'},
#    {'index': 5, 'originalText': 'World'},
#    {'index': 6, 'originalText': 'Health'},
#    {'index': 7, 'originalText': 'Organisation'},
#    {'index': 8, 'originalText': '-LRB-'},
#    {'index': 9, 'originalText': 'WHO'},
#    {'index': 10, 'originalText': '-RRB-'},
#    {'index': 11, 'originalText': 'announcing'},
#    {'index': 12, 'originalText': 'the'},
#    {'index': 13, 'originalText': 'maximum'},
#    {'index': 14, 'originalText': 'pandemic'},
#    {'index': 15, 'originalText': 'alert'},
#    {'index': 16, 'originalText': '--'},
#    {'index': 17, 'originalText': 'currently'},
#    {'index': 18, 'originalText': 'level'},
#    {'index': 19, 'originalText': 'five'},
#    {'index': 20, 'originalText': 'out'},
#    {'index': 21, 'originalText': 'of'},
#    {'index': 22, 'originalText': 'six'},
#    {'index': 23, 'originalText': '--'},
#    {'index': 24, 'originalText': '``'},
#    {'index': 25, 'originalText': 'is'},
#    {'index': 26, 'originalText': 'on'},
#    {'index': 27, 'originalText': 'all'},
#    {'index': 28, 'originalText': 'our'},
#    {'index': 29, 'originalText': 'minds'},
#    {'index': 30, 'originalText': ','},
#    {'index': 31, 'originalText': "''"},
#    {'index': 32, 'originalText': 'admitted'},
#    {'index': 33, 'originalText': 'Vassiliou'},
#    {'index': 34, 'originalText': '.'}]},
#  {'index': 6,
#   'tokens': [{'index': 1, 'originalText': 'Such'},
#    {'index': 2, 'originalText': 'a'},
#    {'index': 3, 'originalText': 'step'},
#    {'index': 4, 'originalText': 'would'},
#    {'index': 5, 'originalText': '``'},
#    {'index': 6, 'originalText': 'make'},
#    {'index': 7, 'originalText': 'it'},
#    {'index': 8, 'originalText': 'even'},
#    {'index': 9, 'originalText': 'more'},
#    {'index': 10, 'originalText': 'important'},
#    {'index': 11, 'originalText': 'for'},
#    {'index': 12, 'originalText': 'the'},
#    {'index': 13, 'originalText': 'vaccine'},
#    {'index': 14, 'originalText': 'to'},
#    {'index': 15, 'originalText': 'be'},
#    {'index': 16, 'originalText': 'equally'},
#    {'index': 17, 'originalText': 'and'},
#    {'index': 18, 'originalText': 'equitably'},
#    {'index': 19, 'originalText': 'distributed'},
#    {'index': 20, 'originalText': ','},
#    {'index': 21, 'originalText': "''"},
#    {'index': 22, 'originalText': 'she'},
#    {'index': 23, 'originalText': 'added'},
#    {'index': 24, 'originalText': '.'}]},
#  {'index': 7,
#   'tokens': [{'index': 1, 'originalText': 'Swine'},
#    {'index': 2, 'originalText': 'flu'},
#    {'index': 3, 'originalText': 'has'},
#    {'index': 4, 'originalText': 'now'},
#    {'index': 5, 'originalText': 'spread'},
#    {'index': 6, 'originalText': 'to'},
#    {'index': 7, 'originalText': '73'},
#    {'index': 8, 'originalText': 'countries'},
#    {'index': 9, 'originalText': 'with'},
#    {'index': 10, 'originalText': '25,288'},
#    {'index': 11, 'originalText': 'people'},
#    {'index': 12, 'originalText': 'known'},
#    {'index': 13, 'originalText': 'to'},
#    {'index': 14, 'originalText': 'have'},
#    {'index': 15, 'originalText': 'been'},
#    {'index': 16, 'originalText': 'infected'},
#    {'index': 17, 'originalText': 'since'},
#    {'index': 18, 'originalText': 'the'},
#    {'index': 19, 'originalText': 'disease'},
#    {'index': 20, 'originalText': 'was'},
#    {'index': 21, 'originalText': 'first'},
#    {'index': 22, 'originalText': 'uncovered'},
#    {'index': 23, 'originalText': 'in'},
#    {'index': 24, 'originalText': 'April'},
#    {'index': 25, 'originalText': ','},
#    {'index': 26, 'originalText': 'WHO'},
#    {'index': 27, 'originalText': 'data'},
#    {'index': 28, 'originalText': 'showed'},
#    {'index': 29, 'originalText': 'Monday'},
#    {'index': 30, 'originalText': '.'}]},
#  {'index': 8,
#   'tokens': [{'index': 1, 'originalText': 'The'},
#    {'index': 2, 'originalText': 'number'},
#    {'index': 3, 'originalText': 'of'},
#    {'index': 4, 'originalText': 'deaths'},
#    {'index': 5, 'originalText': 'has'},
#    {'index': 6, 'originalText': 'risen'},
#    {'index': 7, 'originalText': 'to'},
#    {'index': 8, 'originalText': '139'},
#    {'index': 9, 'originalText': 'according'},
#    {'index': 10, 'originalText': 'to'},
#    {'index': 11, 'originalText': 'the'},
#    {'index': 12, 'originalText': 'latest'},
#    {'index': 13, 'originalText': 'WHO'},
#    {'index': 14, 'originalText': 'tally'},
#    {'index': 15, 'originalText': 'of'},
#    {'index': 16, 'originalText': 'confirmed'},
#    {'index': 17, 'originalText': 'influenza'},
#    {'index': 18, 'originalText': 'A'},
#    {'index': 19, 'originalText': '-LRB-'},
#    {'index': 20, 'originalText': 'H1N1'},
#    {'index': 21, 'originalText': '-RRB-'},
#    {'index': 22, 'originalText': 'cases'},
#    {'index': 23, 'originalText': '.'}]},
#  {'index': 9,
#   'tokens': [{'index': 1, 'originalText': 'Under'},
#    {'index': 2, 'originalText': 'WHO'},
#    {'index': 3, 'originalText': 'guidelines'},
#    {'index': 4, 'originalText': ','},
#    {'index': 5, 'originalText': 'one'},
#    {'index': 6, 'originalText': 'key'},
#    {'index': 7, 'originalText': 'criteria'},
#    {'index': 8, 'originalText': 'for'},
#    {'index': 9, 'originalText': 'a'},
#    {'index': 10, 'originalText': 'move'},
#    {'index': 11, 'originalText': 'to'},
#    {'index': 12, 'originalText': 'the'},
#    {'index': 13, 'originalText': 'highest'},
#    {'index': 14, 'originalText': 'phase'},
#    {'index': 15, 'originalText': 'six'},
#    {'index': 16, 'originalText': 'alert'},
#    {'index': 17, 'originalText': 'would'},
#    {'index': 18, 'originalText': 'be'},
#    {'index': 19, 'originalText': 'established'},
#    {'index': 20, 'originalText': 'community'},
#    {'index': 21, 'originalText': 'spread'},
#    {'index': 22, 'originalText': 'in'},
#    {'index': 23, 'originalText': 'a'},
#    {'index': 24, 'originalText': 'country'},
#    {'index': 25, 'originalText': 'outside'},
#    {'index': 26, 'originalText': 'the'},
#    {'index': 27, 'originalText': 'region'},
#    {'index': 28, 'originalText': 'where'},
#    {'index': 29, 'originalText': 'the'},
#    {'index': 30, 'originalText': 'disease'},
#    {'index': 31, 'originalText': 'was'},
#    {'index': 32, 'originalText': 'initially'},
#    {'index': 33, 'originalText': 'reported'},
#    {'index': 34, 'originalText': ','},
#    {'index': 35, 'originalText': 'in'},
#    {'index': 36, 'originalText': 'this'},
#    {'index': 37, 'originalText': 'case'},
#    {'index': 38, 'originalText': ','},
#    {'index': 39, 'originalText': 'outside'},
#    {'index': 40, 'originalText': 'the'},
#    {'index': 41, 'originalText': 'Americas'},
#    {'index': 42, 'originalText': '.'}]},
#  {'index': 10,
#   'tokens': [{'index': 1, 'originalText': 'So'},
#    {'index': 2, 'originalText': 'far'},
#    {'index': 3, 'originalText': 'the'},
#    {'index': 4, 'originalText': 'majority'},
#    {'index': 5, 'originalText': 'of'},
#    {'index': 6, 'originalText': 'the'},
#    {'index': 7, 'originalText': 'fatalities'},
#    {'index': 8, 'originalText': 'from'},
#    {'index': 9, 'originalText': 'the'},
#    {'index': 10, 'originalText': 'disease'},
#    {'index': 11, 'originalText': 'have'},
#    {'index': 12, 'originalText': 'been'},
#    {'index': 13, 'originalText': 'recorded'},
#    {'index': 14, 'originalText': 'in'},
#    {'index': 15, 'originalText': 'Mexico'},
#    {'index': 16, 'originalText': ','},
#    {'index': 17, 'originalText': 'and'},
#    {'index': 18, 'originalText': 'all'},
#    {'index': 19, 'originalText': 'the'},
#    {'index': 20, 'originalText': 'rest'},
#    {'index': 21, 'originalText': 'in'},
#    {'index': 22, 'originalText': 'the'},
#    {'index': 23, 'originalText': 'Americas'},
#    {'index': 24, 'originalText': '.'}]},
#  {'index': 11,
#   'tokens': [{'index': 1, 'originalText': 'German'},
#    {'index': 2, 'originalText': 'Health'},
#    {'index': 3, 'originalText': 'Minister'},
#    {'index': 4, 'originalText': 'Ulla'},
#    {'index': 5, 'originalText': 'Schmidt'},
#    {'index': 6, 'originalText': ','},
#    {'index': 7, 'originalText': 'attending'},
#    {'index': 8, 'originalText': 'the'},
#    {'index': 9, 'originalText': 'meeting'},
#    {'index': 10, 'originalText': 'in'},
#    {'index': 11, 'originalText': 'Luxembourg'},
#    {'index': 12, 'originalText': ','},
#    {'index': 13, 'originalText': 'echoed'},
#    {'index': 14, 'originalText': 'that'},
#    {'index': 15, 'originalText': 'there'},
#    {'index': 16, 'originalText': 'should'},
#    {'index': 17, 'originalText': 'be'},
#    {'index': 18, 'originalText': 'joint'},
#    {'index': 19, 'originalText': 'European'},
#    {'index': 20, 'originalText': 'analysis'},
#    {'index': 21, 'originalText': 'of'},
#    {'index': 22, 'originalText': 'the'},
#    {'index': 23, 'originalText': 'dangers'},
#    {'index': 24, 'originalText': 'of'},
#    {'index': 25, 'originalText': 'swine'},
#    {'index': 26, 'originalText': 'flu'},
#    {'index': 27, 'originalText': 'and'},
#    {'index': 28, 'originalText': '``'},
#    {'index': 29, 'originalText': 'the'},
#    {'index': 30, 'originalText': 'means'},
#    {'index': 31, 'originalText': 'to'},
#    {'index': 32, 'originalText': 'protect'},
#    {'index': 33, 'originalText': 'citizens'},
#    {'index': 34, 'originalText': "''"},
#    {'index': 35, 'originalText': '.'}]},
#  {'index': 12,
#   'tokens': [{'index': 1, 'originalText': 'Among'},
#    {'index': 2, 'originalText': 'the'},
#    {'index': 3, 'originalText': 'decisions'},
#    {'index': 4, 'originalText': 'to'},
#    {'index': 5, 'originalText': 'be'},
#    {'index': 6, 'originalText': 'made'},
#    {'index': 7, 'originalText': 'are'},
#    {'index': 8, 'originalText': ';'},
#    {'index': 9, 'originalText': 'which'},
#    {'index': 10, 'originalText': 'vaccine'},
#    {'index': 11, 'originalText': 'should'},
#    {'index': 12, 'originalText': 'be'},
#    {'index': 13, 'originalText': 'used'},
#    {'index': 14, 'originalText': ','},
#    {'index': 15, 'originalText': 'how'},
#    {'index': 16, 'originalText': 'much'},
#    {'index': 17, 'originalText': 'vaccine'},
#    {'index': 18, 'originalText': 'should'},
#    {'index': 19, 'originalText': 'be'},
#    {'index': 20, 'originalText': 'produced'},
#    {'index': 21, 'originalText': ','},
#    {'index': 22, 'originalText': 'who'},
#    {'index': 23, 'originalText': 'should'},
#    {'index': 24, 'originalText': 'receive'},
#    {'index': 25, 'originalText': 'it'},
#    {'index': 26, 'originalText': ','},
#    {'index': 27, 'originalText': 'what'},
#    {'index': 28, 'originalText': 'stocks'},
#    {'index': 29, 'originalText': 'should'},
#    {'index': 30, 'originalText': 'be'},
#    {'index': 31, 'originalText': 'kept'},
#    {'index': 32, 'originalText': 'and'},
#    {'index': 33, 'originalText': 'how'},
#    {'index': 34, 'originalText': 'to'},
#    {'index': 35, 'originalText': 'help'},
#    {'index': 36, 'originalText': 'out'},
#    {'index': 37, 'originalText': 'poorer'},
#    {'index': 38, 'originalText': 'nations'},
#    {'index': 39, 'originalText': '.'}]},
#  {'index': 13,
#   'tokens': [{'index': 1, 'originalText': 'Schmidt'},
#    {'index': 2, 'originalText': 'said'},
#    {'index': 3, 'originalText': 'European'},
#    {'index': 4, 'originalText': 'level'},
#    {'index': 5, 'originalText': 'discussions'},
#    {'index': 6, 'originalText': 'were'},
#    {'index': 7, 'originalText': 'important'},
#    {'index': 8, 'originalText': ','},
#    {'index': 9, 'originalText': '``'},
#    {'index': 10, 'originalText': 'otherwise'},
#    {'index': 11, 'originalText': 'we'},
#    {'index': 12, 'originalText': 'risk'},
#    {'index': 13, 'originalText': 'leaving'},
#    {'index': 14, 'originalText': 'the'},
#    {'index': 15, 'originalText': 'playing'},
#    {'index': 16, 'originalText': 'field'},
#    {'index': 17, 'originalText': 'to'},
#    {'index': 18, 'originalText': 'the'},
#    {'index': 19, 'originalText': 'pharmaceutical'},
#    {'index': 20, 'originalText': 'industry'},
#    {'index': 21, 'originalText': '.'},
#    {'index': 22, 'originalText': "''"}]},
#  {'index': 14,
#   'tokens': [{'index': 1, 'originalText': 'Late'},
#    {'index': 2, 'originalText': 'month'},
#    {'index': 3, 'originalText': 'the'},
#    {'index': 4, 'originalText': 'WHO'},
#    {'index': 5, 'originalText': 'said'},
#    {'index': 6, 'originalText': 'it'},
#    {'index': 7, 'originalText': 'had'},
#    {'index': 8, 'originalText': 'sent'},
#    {'index': 9, 'originalText': 'three'},
#    {'index': 10, 'originalText': '``'},
#    {'index': 11, 'originalText': 'seed'},
#    {'index': 12, 'originalText': 'viruses'},
#    {'index': 13, 'originalText': "''"},
#    {'index': 14, 'originalText': 'to'},
#    {'index': 15, 'originalText': 'drug'},
#    {'index': 16, 'originalText': 'companies'},
#    {'index': 17, 'originalText': 'for'},
#    {'index': 18, 'originalText': 'use'},
#    {'index': 19, 'originalText': 'in'},
#    {'index': 20, 'originalText': 'making'},
#    {'index': 21, 'originalText': 'a'},
#    {'index': 22, 'originalText': 'vaccine'},
#    {'index': 23, 'originalText': 'against'},
#    {'index': 24, 'originalText': 'the'},
#    {'index': 25, 'originalText': 'new'},
#    {'index': 26, 'originalText': 'strain'},
#    {'index': 27, 'originalText': 'of'},
#    {'index': 28, 'originalText': 'influenza'},
#    {'index': 29, 'originalText': '.'}]}]

# %% [markdown]
# ## Named Entity Recognition (`named_entity` field)
#
# Create mapping of all recognized named entities and occurances in the text. Aliases and acronyms are automatically merged (using `wikidata`). `PERSON` entities are also merged using the last name heuristic.

# %%
p_entities = parsed_data['named_entity']
p_entities
# Out:
# {'Americas': [[10, 'LOCATION', 41, 41], [11, 'LOCATION', 23, 23]],
#  'Androulla Vassiliou': [[2, 'PERSON', 4, 5]],
#  'EU': [[1, 'ORGANIZATION', 1, 1], [3, 'ORGANIZATION', 36, 36]],
#  'EU Health': [[2, 'ORGANIZATION', 1, 2]],
#  'European': [[2, 'MISC', 12, 12], [12, 'MISC', 19, 19], [14, 'MISC', 3, 3]],
#  'German': [[12, 'MISC', 1, 1]],
#  'Luxembourg': [[3, 'LOCATION', 40, 40], [12, 'LOCATION', 11, 11]],
#  'Mexico': [[11, 'LOCATION', 15, 15]],
#  'Schmidt': [[14, 'PERSON', 1, 1]],
#  'Ulla Schmidt': [[12, 'PERSON', 4, 5]],
#  'Vassiliou': [[6, 'PERSON', 33, 33]],
#  'WHO': [[8, 'MISC', 26, 26], [15, 'ORGANIZATION', 4, 4]],
#  'World Health Organisation': [[6, 'ORGANIZATION', 5, 7]],
#  'day': [[5, 'TIME', 13, 13]]}

# %%
import importlib
from preproc import entity_extractor

# %%
importlib.reload(entity_extractor);

# %%
ee = entity_extractor.EntityExtractor()

# %%
named_types = entity_extractor.NAMED_TYPES

for entity, occurances in p_entities.items():
    for sent_idx, e_type, start_idx, end_idx in occurances:
        if e_type in named_types:
            key = (e_type, entity)
            ee.add_occurance(key, sent_idx-1, start_idx-1, end_idx) # change to index from 0 and exclusive end

# %%
dict(ee.ids)
# Out:
# {('LOCATION', 'Americas'): ('wikidata', 'Q828'),
#  ('LOCATION', 'Luxembourg'): ('wikidata', 'Q32'),
#  ('LOCATION', 'Mexico'): ('wikidata', 'Q96'),
#  ('MISC', 'European'): ('wikidata', 'Q1286'),
#  ('MISC', 'German'): ('wikidata', 'Q188'),
#  ('MISC', 'WHO'): ('wikidata', 'Q7817'),
#  ('ORGANIZATION', 'EU'): ('wikidata', 'Q458'),
#  ('ORGANIZATION', 'EU Health'): ('wikidata', 'Q40901196'),
#  ('ORGANIZATION', 'WHO'): ('wikidata', 'Q7817'),
#  ('ORGANIZATION', 'World Health Organisation'): ('wikidata', 'Q7817'),
#  ('PERSON', 'Androulla Vassiliou'): ('wikidata', 'Q262719'),
#  ('PERSON', 'Schmidt'): ('wikidata', 'Q15240355'),
#  ('PERSON', 'Ulla Schmidt'): ('wikidata', 'Q61307'),
#  ('PERSON', 'Vassiliou'): ('wikidata', 'Q21450206')}

# %%
ee.occurances
# Out:
# {('wikidata', 'Q1286'): {(1, 11, 12), (11, 18, 19), (13, 2, 3)},
#  ('wikidata', 'Q15240355'): {(13, 0, 1)},
#  ('wikidata', 'Q188'): {(11, 0, 1)},
#  ('wikidata', 'Q21450206'): {(5, 32, 33)},
#  ('wikidata', 'Q262719'): {(1, 3, 5)},
#  ('wikidata', 'Q32'): {(2, 39, 40), (11, 10, 11)},
#  ('wikidata', 'Q40901196'): {(1, 0, 2)},
#  ('wikidata', 'Q458'): {(0, 0, 1), (2, 35, 36)},
#  ('wikidata', 'Q61307'): {(11, 3, 5)},
#  ('wikidata', 'Q7817'): {(5, 4, 7), (7, 25, 26), (14, 3, 4)},
#  ('wikidata', 'Q828'): {(9, 40, 41), (10, 22, 23)},
#  ('wikidata', 'Q96'): {(10, 14, 15)}}

# %% [markdown]
# ### Last name merging for `PERSON` types

# %%
len(ee.occurances)
# Out:
# 12

# %%
entity_extractor.merge_people_by_last_name(ee)

# %%
len(ee.occurances)
# Out:
# 10

# %%
dict(ee.ids)
# Out:
# {('LOCATION', 'Americas'): ('wikidata', 'Q828'),
#  ('LOCATION', 'Luxembourg'): ('wikidata', 'Q32'),
#  ('LOCATION', 'Mexico'): ('wikidata', 'Q96'),
#  ('MISC', 'European'): ('wikidata', 'Q1286'),
#  ('MISC', 'German'): ('wikidata', 'Q188'),
#  ('MISC', 'WHO'): ('wikidata', 'Q7817'),
#  ('ORGANIZATION', 'EU'): ('wikidata', 'Q458'),
#  ('ORGANIZATION', 'EU Health'): ('wikidata', 'Q40901196'),
#  ('ORGANIZATION', 'WHO'): ('wikidata', 'Q7817'),
#  ('ORGANIZATION', 'World Health Organisation'): ('wikidata', 'Q7817'),
#  ('PERSON', 'Androulla Vassiliou'): ('wikidata', 'Q21450206'),
#  ('PERSON', 'Schmidt'): ('wikidata', 'Q15240355'),
#  ('PERSON', 'Ulla Schmidt'): ('wikidata', 'Q15240355'),
#  ('PERSON', 'Vassiliou'): ('wikidata', 'Q21450206')}

# %% [markdown]
# ## Annotating Tokens with Entities

# %%
from preproc import annotate

# %%
importlib.reload(annotate);

# %%
annotate.mark_entities(sentences, ee)

# %%
for sentence in sentences:
    for token in sentence['tokens']:
        if 'entity_id' in token:
            print((sentence['index'], token['index']), token['originalText'], token['entity_id'])
# Out:
# (0, 1) EU ('wikidata', 'Q458')
# (1, 1) EU ('wikidata', 'Q40901196')
# (1, 2) Health ('wikidata', 'Q40901196')
# (1, 4) Androulla ('wikidata', 'Q21450206')
# (1, 5) Vassiliou ('wikidata', 'Q21450206')
# (1, 12) European ('wikidata', 'Q1286')
# (2, 36) EU ('wikidata', 'Q458')
# (2, 40) Luxembourg ('wikidata', 'Q32')
# (5, 5) World ('wikidata', 'Q7817')
# (5, 6) Health ('wikidata', 'Q7817')
# (5, 7) Organisation ('wikidata', 'Q7817')
# (5, 33) Vassiliou ('wikidata', 'Q21450206')
# (7, 26) WHO ('wikidata', 'Q7817')
# (9, 41) Americas ('wikidata', 'Q828')
# (10, 15) Mexico ('wikidata', 'Q96')
# (10, 23) Americas ('wikidata', 'Q828')
# (11, 1) German ('wikidata', 'Q188')
# (11, 4) Ulla ('wikidata', 'Q15240355')
# (11, 5) Schmidt ('wikidata', 'Q15240355')
# (11, 11) Luxembourg ('wikidata', 'Q32')
# (11, 19) European ('wikidata', 'Q1286')
# (13, 1) Schmidt ('wikidata', 'Q15240355')
# (13, 3) European ('wikidata', 'Q1286')
# (14, 4) WHO ('wikidata', 'Q7817')

# %% [markdown]
# ## Identifying and Annotating Entity Mentions with Co-reference Chains

# %%
parsed_data['cluster_json']
# Out:
# [[{'end_ind': 2,
#    'mention_type': 'PROPER',
#    'sent_ind': 1,
#    'token_ind': 1,
#    'word': 'EU'},
#   {'end_ind': 3,
#    'mention_type': 'PROPER',
#    'sent_ind': 2,
#    'token_ind': 1,
#    'word': 'EU Health'},
#   {'end_ind': 37,
#    'mention_type': 'PROPER',
#    'sent_ind': 3,
#    'token_ind': 36,
#    'word': 'EU'}],
#  [{'end_ind': 8,
#    'mention_type': 'PROPER',
#    'sent_ind': 2,
#    'token_ind': 1,
#    'word': 'EU Health Commissioner Androulla Vassiliou on Tuesday'},
#   {'end_ind': 34,
#    'mention_type': 'PROPER',
#    'sent_ind': 6,
#    'token_ind': 33,
#    'word': 'Vassiliou'}],
#  [{'end_ind': 22,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 2,
#    'token_ind': 18,
#    'word': 'a swine flu vaccine'},
#   {'end_ind': 24,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 3,
#    'token_ind': 22,
#    'word': 'the vaccine'},
#   {'end_ind': 11,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 5,
#    'token_ind': 9,
#    'word': 'the vaccine'}],
#  [{'end_ind': 31,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 3,
#    'token_ind': 30,
#    'word': 'she'},
#   {'end_ind': 3,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 3,
#    'token_ind': 2,
#    'word': 'I'},
#   {'end_ind': 27,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 3,
#    'token_ind': 26,
#    'word': 'she'},
#   {'end_ind': 32,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 2,
#    'token_ind': 29,
#    'word': 'those most vulnerable'}],
#  [{'end_ind': 12,
#    'mention_type': 'PROPER',
#    'sent_ind': 12,
#    'token_ind': 11,
#    'word': 'Luxembourg'},
#   {'end_ind': 41,
#    'mention_type': 'PROPER',
#    'sent_ind': 3,
#    'token_ind': 40,
#    'word': 'Luxembourg'}],
#  [{'end_ind': 29,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 6,
#    'token_ind': 28,
#    'word': 'our'},
#   {'end_ind': 3,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 4,
#    'token_ind': 2,
#    'word': 'We'},
#   {'end_ind': 3,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 5,
#    'token_ind': 2,
#    'word': 'We'},
#   {'end_ind': 23,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 4,
#    'token_ind': 22,
#    'word': 'we'},
#   {'end_ind': 29,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 3,
#    'token_ind': 28,
#    'word': 'reporters'},
#   {'end_ind': 10,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 6,
#    'token_ind': 9,
#    'word': 'WHO'}],
#  [{'end_ind': 39,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 3,
#    'token_ind': 33,
#    'word': 'a meeting of EU health ministers'},
#   {'end_ind': 10,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 12,
#    'token_ind': 8,
#    'word': 'the meeting'},
#   {'end_ind': 26,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 13,
#    'token_ind': 25,
#    'word': 'it'}],
#  [{'end_ind': 23,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 15,
#    'token_ind': 21,
#    'word': 'a vaccine'},
#   {'end_ind': 8,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 4,
#    'token_ind': 6,
#    'word': 'a vaccine'}],
#  [{'end_ind': 45,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 4,
#    'token_ind': 44,
#    'word': 'she'},
#   {'end_ind': 39,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 4,
#    'token_ind': 37,
#    'word': 'the elderly'},
#   {'end_ind': 23,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 7,
#    'token_ind': 22,
#    'word': 'she'}],
#  [{'end_ind': 16,
#    'mention_type': 'PROPER',
#    'sent_ind': 10,
#    'token_ind': 15,
#    'word': 'six'},
#   {'end_ind': 23,
#    'mention_type': 'PROPER',
#    'sent_ind': 6,
#    'token_ind': 22,
#    'word': 'six'}],
#  [{'end_ind': 24,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 6,
#    'token_ind': 12,
#    'word': 'the maximum pandemic alert -- currently level five out of six --'},
#   {'end_ind': 17,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 10,
#    'token_ind': 15,
#    'word': 'six alert'}],
#  [{'end_ind': 4,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 7,
#    'token_ind': 1,
#    'word': 'Such a step'},
#   {'end_ind': 8,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 7,
#    'token_ind': 7,
#    'word': 'it'}],
#  [{'end_ind': 27,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 12,
#    'token_ind': 25,
#    'word': 'swine flu'},
#   {'end_ind': 3,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 8,
#    'token_ind': 1,
#    'word': 'Swine flu'}],
#  [{'end_ind': 11,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 11,
#    'token_ind': 9,
#    'word': 'the disease'},
#   {'end_ind': 31,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 10,
#    'token_ind': 29,
#    'word': 'the disease'},
#   {'end_ind': 20,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 8,
#    'token_ind': 18,
#    'word': 'the disease'}],
#  [{'end_ind': 25,
#    'mention_type': 'PROPER',
#    'sent_ind': 8,
#    'token_ind': 24,
#    'word': 'April'},
#   {'end_ind': 27,
#    'mention_type': 'PROPER',
#    'sent_ind': 8,
#    'token_ind': 26,
#    'word': 'WHO'}],
#  [{'end_ind': 24,
#    'mention_type': 'PROPER',
#    'sent_ind': 11,
#    'token_ind': 22,
#    'word': 'the Americas'},
#   {'end_ind': 42,
#    'mention_type': 'PROPER',
#    'sent_ind': 10,
#    'token_ind': 40,
#    'word': 'the Americas'}],
#  [{'end_ind': 6,
#    'mention_type': 'PROPER',
#    'sent_ind': 12,
#    'token_ind': 4,
#    'word': 'Ulla Schmidt'},
#   {'end_ind': 2,
#    'mention_type': 'PROPER',
#    'sent_ind': 14,
#    'token_ind': 1,
#    'word': 'Schmidt'}],
#  [{'end_ind': 12,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 14,
#    'token_ind': 11,
#    'word': 'we'},
#   {'end_ind': 34,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 12,
#    'token_ind': 33,
#    'word': 'citizens'}],
#  [{'end_ind': 21,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 14,
#    'token_ind': 18,
#    'word': 'the pharmaceutical industry'}],
#  [{'end_ind': 3,
#    'mention_type': 'NOMINAL',
#    'sent_ind': 15,
#    'token_ind': 1,
#    'word': 'Late month'},
#   {'end_ind': 7,
#    'mention_type': 'PRONOMINAL',
#    'sent_ind': 15,
#    'token_ind': 6,
#    'word': 'it'}]]

# %% [markdown]
# Remap the keys to match corefence output from Stanford CoreNLP.

# %%
coref_chains = [
    [
        {
            'sentNum': m['sent_ind'],
            'startIndex': m['token_ind'],
            'endIndex': m['end_ind']
        } for m in chain
    ] for chain in parsed_data['cluster_json']
]
coref_chains
# Out:
# [[{'endIndex': 2, 'sentNum': 1, 'startIndex': 1},
#   {'endIndex': 3, 'sentNum': 2, 'startIndex': 1},
#   {'endIndex': 37, 'sentNum': 3, 'startIndex': 36}],
#  [{'endIndex': 8, 'sentNum': 2, 'startIndex': 1},
#   {'endIndex': 34, 'sentNum': 6, 'startIndex': 33}],
#  [{'endIndex': 22, 'sentNum': 2, 'startIndex': 18},
#   {'endIndex': 24, 'sentNum': 3, 'startIndex': 22},
#   {'endIndex': 11, 'sentNum': 5, 'startIndex': 9}],
#  [{'endIndex': 31, 'sentNum': 3, 'startIndex': 30},
#   {'endIndex': 3, 'sentNum': 3, 'startIndex': 2},
#   {'endIndex': 27, 'sentNum': 3, 'startIndex': 26},
#   {'endIndex': 32, 'sentNum': 2, 'startIndex': 29}],
#  [{'endIndex': 12, 'sentNum': 12, 'startIndex': 11},
#   {'endIndex': 41, 'sentNum': 3, 'startIndex': 40}],
#  [{'endIndex': 29, 'sentNum': 6, 'startIndex': 28},
#   {'endIndex': 3, 'sentNum': 4, 'startIndex': 2},
#   {'endIndex': 3, 'sentNum': 5, 'startIndex': 2},
#   {'endIndex': 23, 'sentNum': 4, 'startIndex': 22},
#   {'endIndex': 29, 'sentNum': 3, 'startIndex': 28},
#   {'endIndex': 10, 'sentNum': 6, 'startIndex': 9}],
#  [{'endIndex': 39, 'sentNum': 3, 'startIndex': 33},
#   {'endIndex': 10, 'sentNum': 12, 'startIndex': 8},
#   {'endIndex': 26, 'sentNum': 13, 'startIndex': 25}],
#  [{'endIndex': 23, 'sentNum': 15, 'startIndex': 21},
#   {'endIndex': 8, 'sentNum': 4, 'startIndex': 6}],
#  [{'endIndex': 45, 'sentNum': 4, 'startIndex': 44},
#   {'endIndex': 39, 'sentNum': 4, 'startIndex': 37},
#   {'endIndex': 23, 'sentNum': 7, 'startIndex': 22}],
#  [{'endIndex': 16, 'sentNum': 10, 'startIndex': 15},
#   {'endIndex': 23, 'sentNum': 6, 'startIndex': 22}],
#  [{'endIndex': 24, 'sentNum': 6, 'startIndex': 12},
#   {'endIndex': 17, 'sentNum': 10, 'startIndex': 15}],
#  [{'endIndex': 4, 'sentNum': 7, 'startIndex': 1},
#   {'endIndex': 8, 'sentNum': 7, 'startIndex': 7}],
#  [{'endIndex': 27, 'sentNum': 12, 'startIndex': 25},
#   {'endIndex': 3, 'sentNum': 8, 'startIndex': 1}],
#  [{'endIndex': 11, 'sentNum': 11, 'startIndex': 9},
#   {'endIndex': 31, 'sentNum': 10, 'startIndex': 29},
#   {'endIndex': 20, 'sentNum': 8, 'startIndex': 18}],
#  [{'endIndex': 25, 'sentNum': 8, 'startIndex': 24},
#   {'endIndex': 27, 'sentNum': 8, 'startIndex': 26}],
#  [{'endIndex': 24, 'sentNum': 11, 'startIndex': 22},
#   {'endIndex': 42, 'sentNum': 10, 'startIndex': 40}],
#  [{'endIndex': 6, 'sentNum': 12, 'startIndex': 4},
#   {'endIndex': 2, 'sentNum': 14, 'startIndex': 1}],
#  [{'endIndex': 12, 'sentNum': 14, 'startIndex': 11},
#   {'endIndex': 34, 'sentNum': 12, 'startIndex': 33}],
#  [{'endIndex': 21, 'sentNum': 14, 'startIndex': 18}],
#  [{'endIndex': 3, 'sentNum': 15, 'startIndex': 1},
#   {'endIndex': 7, 'sentNum': 15, 'startIndex': 6}]]

# %%
annotate.mark_coref_mentions(sentences, coref_chains)

# %%
for sentence in sentences:
    for token in sentence['tokens']:
        if 'entity_id' in token:
            print((sentence['index'], token['index']), token['originalText'], token['entity_id'])
# Out:
# (0, 1) EU ('wikidata', 'Q458')
# (1, 1) EU ('wikidata', 'Q40901196')
# (1, 2) Health ('wikidata', 'Q40901196')
# (1, 4) Androulla ('wikidata', 'Q21450206')
# (1, 5) Vassiliou ('wikidata', 'Q21450206')
# (1, 12) European ('wikidata', 'Q1286')
# (2, 33) a ('wikidata', 'Q458')
# (2, 34) meeting ('wikidata', 'Q458')
# (2, 35) of ('wikidata', 'Q458')
# (2, 36) EU ('wikidata', 'Q458')
# (2, 37) health ('wikidata', 'Q458')
# (2, 38) ministers ('wikidata', 'Q458')
# (2, 40) Luxembourg ('wikidata', 'Q32')
# (5, 5) World ('wikidata', 'Q7817')
# (5, 6) Health ('wikidata', 'Q7817')
# (5, 7) Organisation ('wikidata', 'Q7817')
# (5, 33) Vassiliou ('wikidata', 'Q21450206')
# (7, 24) April ('wikidata', 'Q7817')
# (7, 26) WHO ('wikidata', 'Q7817')
# (9, 40) the ('wikidata', 'Q828')
# (9, 41) Americas ('wikidata', 'Q828')
# (10, 15) Mexico ('wikidata', 'Q96')
# (10, 22) the ('wikidata', 'Q828')
# (10, 23) Americas ('wikidata', 'Q828')
# (11, 1) German ('wikidata', 'Q188')
# (11, 4) Ulla ('wikidata', 'Q15240355')
# (11, 5) Schmidt ('wikidata', 'Q15240355')
# (11, 8) the ('wikidata', 'Q458')
# (11, 9) meeting ('wikidata', 'Q458')
# (11, 11) Luxembourg ('wikidata', 'Q32')
# (11, 19) European ('wikidata', 'Q1286')
# (12, 25) it ('wikidata', 'Q458')
# (13, 1) Schmidt ('wikidata', 'Q15240355')
# (13, 3) European ('wikidata', 'Q1286')
# (14, 4) WHO ('wikidata', 'Q7817')
